# %% [markdown]
# - 노션: https://www.notion.so/likelion-aischool/3-4-30028ed19f144776a8b54e994dfa3483

# %% [markdown]
# # 데이터 준비

# %% [markdown]
# < 데이터 준비 순서 >
#
# * 1. 진짜 음성 데이터 다운 - AI Hub
# * 2. 가짜 음성 데이터 다운 - AI Hub 대본을 네이버 클로바로 더빙
# ** 2 - 1. 가짜 음성이 길어서 4초 단위로 자름

# %% [markdown]
# - 클로바 Fake voice 음성 자르는 모듈

# %% [markdown]
# # 데이터 분할

# %% [markdown]
# - 7( 9 개 ), 8( 2 개 ), 11( 7 개 ), 17( 6 개 )
#   - 여러 개의 wav파일이라 합치고 나누기 진행
# - 15번 파일: 확장자가 wav와 mp3가 섞여서 따로 처리 필요
# - 16번 파일: 확장자가 mp3 따로 처리 필요

# %% [markdown]
# ## 1

# %% [markdown]
# - 첫 번째 fake voice 나누기
#   - 1.seperate_fake_voice 파일에 wav로 저장

# %%
import os
import librosa
import soundfile as sf

def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/1_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )

wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/1_fake_voice_source.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/1.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 2

# %% [markdown]
# - 두 번째 fake voice 나누기
#   - 2.seperate_fake_voice 파일에 wav로 저장

# %%
import os
import librosa
import soundfile as sf

def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/2_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )

wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/2_fake_voice_source.mp3'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/2.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 3

# %% [markdown]
# - 세 번째 fake voice 나누기
#   - 3.seperate_fake_voice 파일에 wav로 저장

# %%
import os
import librosa
import soundfile as sf

def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/3_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )

wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/3_fake_voice_source.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/3.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 4

# %% [markdown]
# - 네 번째 fake voice 나누기
#   - 4.seperate_fake_voice 파일에 wav로 저장

# %%
import os
import librosa
import soundfile as sf

def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/4_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )

wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/4_fake_voice_source.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/4.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 5

# %% [markdown]
# - 다섯 번째 fake voice 나누기
#   - 5.seperate_fake_voice 파일에 wav로 저장

# %%
import os
import librosa
import soundfile as sf

def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/5_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )

wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/5_fake_voice_source.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/5.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 6

# %% [markdown]
# - 여섯 번째 fake voice 나누기
#   - 6.seperate_fake_voice 파일에 wav로 저장

# %%
import os
import librosa
import soundfile as sf

def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/6_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )

wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/6_fake_voice_source.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/6.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 7

# %% [markdown]
# - 일곱 번째 fake voice 나누기
#   - 7.seperate_fake_voice 파일에 wav로 저장

# %%
# wave 합치기
# !pip install pydub

# %%
import os
import librosa
import soundfile as sf
from pydub import AudioSegment

count = 0
result = None
data = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/7_fake_voice_source'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/7_fake_voice_source/sum_7_fake_source'

for n in range( 1 ):
  for file in os.listdir( data )[ n : n + 9 ]:
    print( f'read file {file}' )
    if result is None:
      result = AudioSegment.from_wav( os.path.join( data, file ) )
    else:
      f_to_add = AudioSegment.from_wav( os.path.join( data, file ) )
      result += f_to_add

  # result.export( f'eng_discussion_{n}.wav', format = 'wav' )
  # f"{ output_dir }/8_segment_{ start_sample // segment_samples }.wav"

  result.export( f'{ output_dir }/sum_7_segment.wav' )

  print( f'{n} done' )
  reuslt = None
# Out:
# read file 7-1_fakevoice_source.wav
# read file 7-2_fakevoice_source.wav
# read file 7-3_fakevoice_source.wav
# read file 7-4_fakevoice_source.wav
# read file 7-5_fakevoice_source.wav
# read file 7-6_fakevoice_source.wav
# read file 7-7_fakevoice_source.wav
# read file 7-8_fakevoice_source.wav
# read file 7-9_fakevoice_source.wav
# 0 done

# %%
import os
import librosa
import soundfile as sf


def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/7_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )


wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/7_fake_voice_source/sum_7_fake_source/sum_7_segment.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/7.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 8

# %% [markdown]
# - 여덟 번째 fake voice 나누기
#   - 8.seperate_fake_voice 파일에 wav로 저장

# %%
# wave 합치기
# !pip install pydub

# %%
from pydub import AudioSegment

f1 = AudioSegment.from_wav( '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/8_fakevoice_source/8-1_fakevoice_source.wav' )
f2 = AudioSegment.from_wav( '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/8_fakevoice_source/8-2_fakevoice_source.wav' )

f3 = f1 + f2
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/8_fakevoice_source'

f3.export(  'test.wav', format= 'wav' )
# Out:
# <_io.BufferedRandom name='test.wav'>

# %%
import os
import librosa
import soundfile as sf


def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/8_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )


wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/8_fake_voice_source/test.wav'

output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/8.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 9

# %% [markdown]
# - 아홉 번째 fake voice 나누기
#   - 9.seperate_fake_voice 파일에 wav로 저장

# %%
import os
import librosa
import soundfile as sf

def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/5_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )

wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/9_fakevoice_source.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/9.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 10

# %% [markdown]
# - 열 번째 fake voice 나누기
#   - 10.seperate_fake_voice 파일에 wav로 저장

# %%
import os
import librosa
import soundfile as sf

def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/10_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )

wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/10_fake_voice_source.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/10.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 11

# %% [markdown]
# - 열한 번째 fake voice 나누기
#   - 11.seperate_fake_voice 파일에 wav로 저장

# %%
# wave 합치기
# !pip install pydub

# %%
import os
import librosa
import soundfile as sf
from pydub import AudioSegment

count = 0
result = None
data = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/11_fakevoice_source'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/11_fakevoice_source/sum_fake_voice_source'

for n in range( 1 ):
  for file in os.listdir( data )[ n : n + 7 ]:
    print( f'read file {file}' )
    if result is None:
      result = AudioSegment.from_wav( os.path.join( data, file ) )
    else:
      f_to_add = AudioSegment.from_wav( os.path.join( data, file ) )
      result += f_to_add

  # result.export( f'eng_discussion_{n}.wav', format = 'wav' )
  # f"{ output_dir }/8_segment_{ start_sample // segment_samples }.wav"

  result.export( f'{ output_dir }/sum_11_segment.wav' )

  print( f'{n} done' )
  reuslt = None
# Out:
# read file 11-1_fake_voice_source.wav
# read file 11-7_fake_voice_source.wav
# read file 11-2_fake_voice_source.wav
# read file 11-3_fake_voice_source.wav
# read file 11-6_fake_voice_source.wav
# read file 11-5_fake_voice_source.wav
# read file 11-4_fake_voice_source.wav
# 0 done

# %%
import os
import librosa
import soundfile as sf


def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/11_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )


wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/11_fakevoice_source/sum_fake_voice_source/sum_11_segment.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/11.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 12

# %% [markdown]
# - 열두 번째 fake voice 나누기
#   - 12.seperate_fake_voice 파일에 wav로 저장

# %%
import os
import librosa
import soundfile as sf

def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/12_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )

wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/12_fake_voice_source.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/12.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 13

# %% [markdown]
# - 열세 번째 fake voice 나누기
#   - 13.seperate_fake_voice 파일에 wav로 저장

# %%
import os
import librosa
import soundfile as sf

def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/13_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )

wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/13_fake_voice_source.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/13.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 14

# %% [markdown]
# - 열네 번째 fake voice 나누기
#   - 14.seperate_fake_voice 파일에 wav로 저장

# %%
import os
import librosa
import soundfile as sf

def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/14_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )

wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/14_fake_voice_source.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/14.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# ## 17

# %% [markdown]
# - 열일곱 번째 fake voice 나누기
#   - 17.seperate_fake_voice 파일에 wav로 저장

# %%
# wave 합치기
# !pip install pydub

# %%
import os
import librosa
import soundfile as sf
from pydub import AudioSegment

count = 0
result = None
data = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/17_fake_voice_source'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/17_fake_voice_source/sum_17_fake_voice_source'

for n in range( 1 ):
  for file in os.listdir( data )[ n : n + 6 ]:
    print( f'read file {file}' )
    if result is None:
      result = AudioSegment.from_wav( os.path.join( data, file ) )
    else:
      f_to_add = AudioSegment.from_wav( os.path.join( data, file ) )
      result += f_to_add

  # result.export( f'eng_discussion_{n}.wav', format = 'wav' )
  # f"{ output_dir }/8_segment_{ start_sample // segment_samples }.wav"

  result.export( f'{ output_dir }/sum_17_segment.wav' )

  print( f'{n} done' )
  reuslt = None
# Out:
# read file 17-4_fake_voice_source.wav
# read file 17-2_fake_voice_source.wav
# read file 17-1_fake_voice_source.wav
# read file 17-5_fake_voice_source.wav
# read file 17-3_fake_voice_source.wav
# read file 17-6_fake_voice_source.wav
# 0 done

# %%
import os
import librosa
import soundfile as sf


def split_and_save( wav_path, output_dir, segment_length = 4 ):

    """
    - wav_path : 로드할 WAV 파일 또는 MP3 파일의 경로
    - output_dir : WAV 파일들을 저장할 디렉토리 경로
    - segment_length : 분할할 세그먼트의 길이 (초 단위, 기본값은 4초)
    """

    # WAV 파일 또는 MP3 파일 로드
    # sr을 None으로 하면 원본 샘플링 레이트를 사용
    # 리턴 값
    # y는 오디오의 시계열 데이터가 저장되어 있는 넘파이 배열
    # sr은 로드된 오디오 파일에 포함된 총 샘플 수
    y, sr = librosa.load( wav_path, sr = None )

    # 샘플의 총 길이 계산
    total_samples = len( y )

    # 전체 오디오를 segment_length 초 단위로 나눈 각 세그먼트의 샘플 수 계산
    segment_samples = segment_length * sr

    # 지정된 길이 segment_samples로 분할하여 WAV 파일로 저장
    for start_sample in range( 0, total_samples, segment_samples ):
        end_sample = start_sample + segment_samples
        output_path = f"{ output_dir }/17_segment_{ start_sample // segment_samples }.wav"

        # 여기서는 segment로 분할된 오디오 데이터를 WAV 파일로 저장
        sf.write( output_path, y[ start_sample:end_sample ], sr )


wav_path = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/fake_voice_source/17_fake_voice_source/sum_17_fake_voice_source/sum_17_segment.wav'
output_dir = '/content/drive/MyDrive/멋사_데이터분석스쿨/멘토링/seperate_fake_voice/17.seperate_fake_voice'
split_and_save( wav_path, output_dir )

# %% [markdown]
# # 결과

# %% [markdown]
# - 첫   번째 fake data 4초 분할 데이터 수: 443 개
# - 두   번째 fake data 4초 분할 데이터 수: 149 개
# - 세   번째 fake data 4초 분할 데이터 수: 448 개
# - 네   번째 fake data 4초 분할 데이터 수: 333 개
# - 다섯 번째 fake data 4초 분할 데이터 수: 216 개
# - 여섯 번째 fake data 4초 분할 데이터 수: 170 개
# - 일곱 번째 fake data 4초 분할 데이터 수: 651 개
# - 여덟 번째 fake data 4초 분할 데이터 수: 182 개
# - 아홉 번째 fake data 4초 분할 데이터 수: 118 개
# - 열   번째 fake data 4초 분할 데이터 수: 287 개
# - 열한   번째 fake data 4초 분할 데이터 수: 449 개
# - 열두   번째 fake data 4초 분할 데이터 수: 447 개
# - 열세   번째 fake data 4초 분할 데이터 수: 125 개
# - 열네   번째 fake data 4초 분할 데이터 수: 363 개
# - 열일곱   번째 fake data 4초 분할 데이터 수: 726 개
#
#
#
# ---
#
#
# - 총 분할 데이터 수: 5, 107 개
#
# - 최소 목표 데이터 수: 5000 개
#   - 남은 데이터 수: 0 개
